# %%
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

df=sns.load_dataset('titanic')
df.head(10)
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0         0       3    male  22.0      1      0   7.2500        S   Third
# 1         1       1  female  38.0      1      0  71.2833        C   First
# 2         1       3  female  26.0      0      0   7.9250        S   Third
# 3         1       1  female  35.0      1      0  53.1000        S   First
# 4         0       3    male  35.0      0      0   8.0500        S   Third
# 5         0       3    male   NaN      0      0   8.4583        Q   Third
# 6         0       1    male  54.0      0      0  51.8625        S   First
# 7         0       3    male   2.0      3      1  21.0750        S   Third
# 8         1       3  female  27.0      0      2  11.1333        S   Third
# 9         1       2  female  14.0      1      0  30.0708        C  Second
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True
# 5    man        True  NaN   Queenstown    no   True
# 6    man        True    E  Southampton    no   True
# 7  child       False  NaN  Southampton    no  False
# 8  woman       False  NaN  Southampton   yes  False
# 9  child       False  NaN    Cherbourg   yes  False

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     891 non-null    int64
#  1   pclass       891 non-null    int64
#  2   sex          891 non-null    object
#  3   age          714 non-null    float64
#  4   sibsp        891 non-null    int64
#  5   parch        891 non-null    int64
#  6   fare         891 non-null    float64
#  7   embarked     889 non-null    object
#  8   class        891 non-null    category
#  9   who          891 non-null    object
#  10  adult_male   891 non-null    bool
#  11  deck         203 non-null    category
#  12  embark_town  889 non-null    object
#  13  alive        891 non-null    object
#  14  alone        891 non-null    bool
# dtypes: bool(2), category(2), float64(2), int64(4), object(5)
# memory usage: 80.7+ KB

# %%
sns.barplot(x="class",y="fare",data=df)
# Out:
# <Axes: xlabel='class', ylabel='fare'>

# %%
df.groupby("class")["fare"].mean()
# Out:
# C:\Users\Elif\AppData\Local\Temp\ipykernel_14568\3866346670.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df.groupby("class")["fare"].mean()
# class
# First     84.154687
# Second    20.662183
# Third     13.675550
# Name: fare, dtype: float64

# %%
sns.barplot(x="class",y="fare",hue="who",data=df)
# Out:
# <Axes: xlabel='class', ylabel='fare'>

# %%
sns.countplot(x="class",data=df)
# Out:
# <Axes: xlabel='class', ylabel='count'>

# %%
df.groupby("class").count()
# Out:
# C:\Users\Elif\AppData\Local\Temp\ipykernel_14568\25708849.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df.groupby("class").count()
#         survived  pclass  sex  age  sibsp  parch  fare  embarked  who  \
# class
# First        216     216  216  186    216    216   216       214  216
# Second       184     184  184  173    184    184   184       184  184
# Third        491     491  491  355    491    491   491       491  491
#
#         adult_male  deck  embark_town  alive  alone
# class
# First          216   175          214    216    216
# Second         184    16          184    184    184
# Third          491    12          491    491    491

# %%
sns.countplot(x="class",hue="who",data=df)
# Out:
# <Axes: xlabel='class', ylabel='count'>

# %%
sns.boxplot(x="fare",data=df)
# Out:
# <Axes: xlabel='fare'>

# %%
df["fare"].describe()
# Out:
# count    891.000000
# mean      32.204208
# std       49.693429
# min        0.000000
# 25%        7.910400
# 50%       14.454200
# 75%       31.000000
# max      512.329200
# Name: fare, dtype: float64

# %%
sns.boxplot(x="class",y="fare",data=df)
# Out:
# <Axes: xlabel='class', ylabel='fare'>

# %%
sns.boxplot(x="class",y="fare",hue="who",data=df)
# Out:
# <Axes: xlabel='class', ylabel='fare'>

# %%
sns.swarmplot(x="fare",data=df)
# Out:
# <Axes: xlabel='fare'>
# C:\Users\Elif\anaconda3\Lib\site-packages\seaborn\categorical.py:3399: UserWarning: 57.1% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %%
sns.swarmplot(x="who",y="fare",data=df)
# Out:
# C:\Users\Elif\anaconda3\Lib\site-packages\seaborn\categorical.py:3399: UserWarning: 67.4% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\Elif\anaconda3\Lib\site-packages\seaborn\categorical.py:3399: UserWarning: 41.0% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# <Axes: xlabel='who', ylabel='fare'>
# C:\Users\Elif\anaconda3\Lib\site-packages\seaborn\categorical.py:3399: UserWarning: 72.8% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\Elif\anaconda3\Lib\site-packages\seaborn\categorical.py:3399: UserWarning: 46.1% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\Elif\anaconda3\Lib\site-packages\seaborn\categorical.py:3399: UserWarning: 16.9% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %%
sns.swarmplot(x="who",y="fare",hue="class",data=df)
# Out:
# C:\Users\Elif\anaconda3\Lib\site-packages\seaborn\categorical.py:3399: UserWarning: 67.4% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\Elif\anaconda3\Lib\site-packages\seaborn\categorical.py:3399: UserWarning: 41.0% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# <Axes: xlabel='who', ylabel='fare'>
# C:\Users\Elif\anaconda3\Lib\site-packages\seaborn\categorical.py:3399: UserWarning: 72.8% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\Elif\anaconda3\Lib\site-packages\seaborn\categorical.py:3399: UserWarning: 46.1% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\Elif\anaconda3\Lib\site-packages\seaborn\categorical.py:3399: UserWarning: 16.9% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %%
sns.jointplot(x="age",y="fare",kind="hex",data=df)

# %%
sns.jointplot(x="age",y="fare",kind="kde",data=df)

# %%
sns.pointplot(x="who",y="fare",data=df)
# Out:
# <Axes: xlabel='who', ylabel='fare'>

# %%
df.groupby("who")["fare"].mean()
# Out:
# who
# child    32.785795
# man      24.864182
# woman    46.570711
# Name: fare, dtype: float64

# %%
sns.lmplot(x="age",y="fare",data=df)

# %%
sns.lmplot(x="age",y="fare",hue="class",data=df)

# %%
sns.lmplot(x="age",y="fare",hue="class",col="who",data=df)

# %%
sns.kdeplot(x="fare",data=df)
# Out:
# <Axes: xlabel='fare', ylabel='Density'>

# %%
sns.kdeplot(x="fare",hue="class",data=df)
# Out:
# <Axes: xlabel='fare', ylabel='Density'>

# %%
sns.kdeplot(x="fare",y="age",data=df)
# Out:
# <Axes: xlabel='fare', ylabel='age'>

# %%
sns.kdeplot(x="fare",y="age",hue="who",data=df)
# Out:
# <Axes: xlabel='fare', ylabel='age'>

# %%
sns.violinplot(x="fare",data=df)
# Out:
# <Axes: xlabel='fare'>

# %%
sns.violinplot(x="fare",y="age",data=df)
# Out:
# <Axes: xlabel='fare', ylabel='age'>

# %%
sns.violinplot(x="class",y="age",hue="who",data=df)
# Out:
# <Axes: xlabel='class', ylabel='age'>
